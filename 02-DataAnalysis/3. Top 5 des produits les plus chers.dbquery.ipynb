-- %%
--Top 5 des produits les plus chers :
--Trouvez les 5 produits les plus chers en
--termes de prix (ListPrice).
--(Table : Product)

select 
 * 
from 
atb_adventureworks.saleslt.product 
order by ListPrice desc limit 5
