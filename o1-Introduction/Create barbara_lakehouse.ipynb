# %%
# %sql
/* Find the managed location under Catalog >> dbw_<name>_dataplatform_dev_001 >> Details >> Storage root*/
CREATE CATALOG IF NOT EXISTS barbara_lakehouse MANAGED LOCATION 'abfss://unity-catalog-storage@dbstoragebjbcn3qtyymkq.dfs.core.windows.net/7405616448833658';
