-- %%
%sql
DROP CATALOG IF EXISTS atb_adventureworks;
DROP CONNECTION IF EXISTS atb_connection_to_sql_datasource;

-- %%
%sql
CREATE CONNECTION IF NOT EXISTS atb_connection_to_sql_datasource TYPE sqlserver
OPTIONS (
  host 'sql-atb-datasource-prod-002.database.windows.net',
  port '1433',
  user 'atb-admin',
  password 'cas-ia2025'
);

-- %%
%sql
CREATE FOREIGN CATALOG IF NOT EXISTS atb_adventureworks USING CONNECTION atb_connection_to_sql_datasource
OPTIONS (database 'sqldb-atb-adventureworks-prod-001');

-- %%
SELECT * FROM atb_adventureworks.saleslt.customer
