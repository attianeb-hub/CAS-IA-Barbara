-- %%
--Partager la couche Gold :
--Configurez la couche gold en lecture
--seule pour un de vos collègues.

--La couche Gold a été partagée en lecture seule via Unity Catalog en appliquant les privilèges USE SCHEMA et SELECT au niveau du schéma, garantissant un accès analytique --sans possibilité de modification des données.
