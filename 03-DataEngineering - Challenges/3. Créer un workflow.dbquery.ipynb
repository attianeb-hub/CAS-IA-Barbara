-- %%
--3. Créer un workflow :
--Configurez un job dans workflow de
--Databricks qui va charger les couches
--Bronze et Silver de votre Lakehouse.

-- Création du job via 'Tâches et pipelines' > 'Créer un job'
-- Ajouter les tâches pour les différents notebooks (Notebook Bronze et Notebook Silver)
-- Exécuter le job
