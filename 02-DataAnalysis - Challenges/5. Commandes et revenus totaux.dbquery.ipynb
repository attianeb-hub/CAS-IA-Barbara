-- %%
--Commandes et revenus totaux :
--Calculez le montant total des revenus
--générés par toutes les commandes
--(TotalDue).
--(Table : SalesOrderHeader) -

select sum(TotalDue) from atb_adventureworks.saleslt.salesorderheader
